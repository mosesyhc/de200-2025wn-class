# %% [markdown]
# # Homework Schedule
#
# |                  **Topic**                |**Duration**            |
# |-------------------------------------------|:----------------------:|
# | HW 1: Data manipulation                   | Jan 21 - Jan 28        |
# | HW 2: Data analysis                       | Jan 30 - Feb 6         |
# | HW 3: Data modeling                       | Feb 11 - Feb 18        |
# | HW 4: Data retrieval                      | Feb 18 - Feb 25        |
# | HW 5: Data visualization                  | Feb 27 - Mar 5         |
