# %% [markdown]
# # Application Programming Interface (API)
#
# This document introduces the use of API to access and query data.  We focus on data access with APIs in this document.

# %% [markdown]
# ## What is an API?

# %% [markdown]
# Broadly speaking, an API is a set of rules and procedures that facilitate interactions between computers and their applications.

# %% [markdown]
# A very common type of API is the **Web API**, which, among other things, allows users to query a remote database over the internet.

# %% [markdown]
# An API specifies **how** a user or application accesses the data.
#
# Examples:
# - Twitter: tweets, users, replies, etc.
# - Art Institute of Chicago: artworks, exhibits, ticketing, etc.
# - New York Times archive: articles, headlines, book reviews, etc.

# %% [markdown]
# ### Representational State Transfer (REST)

# %% [markdown]
# RESTful
# - APIs are convenient for querying databases by URLs.
# - requests are self-contained, meaning that they do not rely on previous requests.
# - responses can be cached to improve server response time.

# %% [markdown]
# **General methods:**
#
# - GET: access resources located at a URL
# - POST: send data to the server
# - PUT: update existing resources
# - DELETE: delete resources in a server

# %% [markdown]
# ## Request via a URL

# %% [markdown]
# |![url-example](../img/url.svg)|
# |:---:|
# |Anatomy of a URL request (rows.com)|

# %% [markdown]
# ## Example: Art Institute of Chicago API
#
# The Art Institute of Chicago hosts a JSON-response API.  The preferrable way of using an API is to refer to its documentation, e.g. https://api.artic.edu/docs/.

# %% [markdown]
# **Important for any API usage (Terms and conditions):**
#
# - Check rate limits
# - Check authentication methods

# %%
import requests  # requests.readthedocs.io/
import pandas as pd

# %% [markdown]
# ### First request

# %%
url_artist = 'https://api.artic.edu/api/v1/artists'

r = requests.get(url_artist)

# %%
artists = r.json()

# %%
artists['pagination']
# Out:
# {'total': 14105,
#  'limit': 12,
#  'offset': 0,
#  'total_pages': 1176,
#  'current_page': 1,
#  'next_url': 'https://api.artic.edu/api/v1/artists?page=2'}

# %% [markdown]
# **Note:** We only retrieve 12 records from a total of > 10000 records.

# %% [markdown]
# ### Request with parameters

# %%
r100 = requests.get(url_artist, params={'limit': 100, 'page':2})

# %%
artists_100 = r100.json()

# %%
artist_data = artists_100['data']

# %%
df = pd.DataFrame(artist_data)

# %%
df
# Out:
#        id api_model                                   api_link  \
# 0   76531    agents  https://api.artic.edu/api/v1/agents/76531
# 1   74323    agents  https://api.artic.edu/api/v1/agents/74323
# 2   74315    agents  https://api.artic.edu/api/v1/agents/74315
# 3   70737    agents  https://api.artic.edu/api/v1/agents/70737
# 4   69511    agents  https://api.artic.edu/api/v1/agents/69511
# ..    ...       ...                                        ...
# 95  48830    agents  https://api.artic.edu/api/v1/agents/48830
# 96  42473    agents  https://api.artic.edu/api/v1/agents/42473
# 97  41841    agents  https://api.artic.edu/api/v1/agents/41841
# 98  30441    agents  https://api.artic.edu/api/v1/agents/30441
# 99   8516    agents   https://api.artic.edu/api/v1/agents/8516
#
#                         title                  sort_title  \
# 0      Carlo Ernesto Liverati     Liverati, Carlo Ernesto
# 1               Nicolas Bazin              Bazin, Nicolas
# 2        Johann Jakob Gräsman       Gräsman, Johann Jakob
# 3      Johann Baptist Klauber     Klauber, Johann Baptist
# 4                Alfred Jones               Jones, Alfred
# ..                        ...                         ...
# 95        Gioacchino Assereto        Assereto, Gioacchino
# 96          Valentin Lefebvre          Lefebvre, Valentin
# 97    Carlo Innocenzo Carlone    Carlone, Carlo Innocenzo
# 98      Marco Angolo del Moro      Angolo del Moro, Marco
# 99  Giovanni Battista Fontana  Fontana, Giovanni Battista
#
#                                            alt_titles  is_artist  birth_date  \
# 0                   [C. E. Liveratif, C. E. Liverati]       True      1805.0
# 1                                                None       True         NaN
# 2     [Johann Jakob Kresman, Johann Jacob Graessmann]       True      1726.0
# 3                                 [Johann B. Klauber]       True      1712.0
# 4                                                None       True      1819.0
# ..                                                ...        ...         ...
# 95  [Giovacchino Asserto, Giovacchino Axareto, Gio...       True      1600.0
# 96  [Valentin Lefevre, Valentin LeFebre, Valentin ...       True      1641.0
# 97  [Carlo Carlone, Carlo Carlone, (Innocenz?), Ca...       True      1686.0
# 98  [Marco Angelo del Moro, Marco del Moro, Marco ...       True         NaN
# 99                                               None       True      1524.0
#
#     death_date description ulan_id  \
# 0       1844.0        None    None
# 1          NaN        None    None
# 2       1759.0        None    None
# 3       1787.0        None    None
# 4       1900.0        None    None
# ..         ...         ...     ...
# 95      1649.0        None    None
# 96      1680.0        None    None
# 97      1775.0        None    None
# 98         NaN        None    None
# 99      1587.0        None    None
#
#                              suggest_autocomplete_all  \
# 0   {'input': ['Carlo Ernesto Liverati', 'Liverati...
# 1   {'input': ['Nicolas Bazin', 'Bazin, Nicolas'],...
# 2   {'input': ['Johann Jakob Gräsman', 'Gräsman, J...
# 3   {'input': ['Johann Baptist Klauber', 'Klauber,...
# 4   {'input': ['Alfred Jones', 'Jones, Alfred'], '...
# ..                                                ...
# 95  {'input': ['Gioacchino Assereto', 'Assereto, G...
# 96  {'input': ['Valentin Lefebvre', 'Lefebvre, Val...
# 97  {'input': ['Carlo Innocenzo Carlone', 'Carlone...
# 98  {'input': ['Marco Angolo del Moro', 'Angolo de...
# 99  {'input': ['Giovanni Battista Fontana', 'Fonta...
#
#             source_updated_at                 updated_at  \
# 0   2025-01-28T18:05:32-06:00  2025-01-28T18:10:22-06:00
# 1   2025-01-28T18:05:32-06:00  2025-01-28T18:10:22-06:00
# 2   2025-01-28T18:05:32-06:00  2025-01-28T18:10:22-06:00
# 3   2025-01-28T18:05:32-06:00  2025-01-28T18:10:22-06:00
# 4   2025-01-28T18:05:32-06:00  2025-01-28T18:10:22-06:00
# ..                        ...                        ...
# 95  2025-01-13T09:14:56-06:00  2025-01-13T09:16:21-06:00
# 96  2025-01-13T09:14:56-06:00  2025-01-13T09:16:21-06:00
# 97  2025-01-13T09:14:56-06:00  2025-01-13T09:16:21-06:00
# 98  2025-01-13T09:14:56-06:00  2025-01-13T09:16:21-06:00
# 99  2025-01-13T09:14:56-06:00  2025-01-13T09:16:21-06:00
#
#                     timestamp suggest_autocomplete_boosted
# 0   2025-02-18T10:13:14-06:00                          NaN
# 1   2025-02-18T10:13:14-06:00                          NaN
# 2   2025-02-18T10:13:14-06:00                          NaN
# 3   2025-02-18T10:13:14-06:00                          NaN
# 4   2025-02-18T10:13:14-06:00                          NaN
# ..                        ...                          ...
# 95  2025-02-18T10:13:14-06:00                          NaN
# 96  2025-02-18T10:13:14-06:00                          NaN
# 97  2025-02-18T10:13:14-06:00                          NaN
# 98  2025-02-18T10:13:14-06:00                          NaN
# 99  2025-02-18T10:13:14-06:00                          NaN
#
# [100 rows x 16 columns]

# %% [markdown]
# ### A considerable way to retrieve multiple pages of data

# %% [markdown]
# 1. Check how much data there are.
# 2. Use a for loop with `time.sleep()`.

# %% [markdown]
# **Note:* Even though we can "scrape" through the entire database, we typically should not.  See for example, discussion in [Data dump vs API](https://api.artic.edu/docs/#data-dumps-vs-api).

# %% [markdown]
# ### Search query
#
# Simply having access or a copy of the data is not inheritly useful.  Most APIs allow for either filtering or searching.

# %%
url_artist_search = url_artist + '/search'

# %% [markdown]
# ## Practice - ARTIC API
# Several endpoints for this API include `artists`, `exhibits`, `artworks`, etc.  Refer to https://api.artic.edu/docs/#endpoints.
#
# 1. How many artworks are in the Art Institute collection?
# 2. Find the exhibits that has "Van Gogh" in the title.
# 3. Search for a painting called "A Sunday on La Grande Jatte".  Who is the artist?  When was it painted?

# %%
url_artwork = 'https://api.artic.edu/api/v1/artworks'

r = requests.get(url_artwork)

# %%
# Out:
# <Response [200]>

# %%
url_exhibit = 'https://api.artic.edu/api/v1/exhibitions/search?q=van gogh'

r = requests.get(url_exhibit, params = {'limit': 40})

# %%
df_vangogh = pd.DataFrame(r.json()['data'])

# %%
df_vangogh
# Out:
#         _score    id    api_model  \
# 0   430.481200  3070  exhibitions
# 1   409.763700  1865  exhibitions
# 2   409.057070  3672  exhibitions
# 3   390.981630  2518  exhibitions
# 4   343.150940  3390  exhibitions
# 5   331.616820  2835  exhibitions
# 6   330.616820  9639  exhibitions
# 7   329.910160  7177  exhibitions
# 8   295.761700  8423  exhibitions
# 9   294.761700  5874  exhibitions
# 10  284.920650  3389  exhibitions
# 11  260.023830  5757  exhibitions
# 12  252.419620  7780  exhibitions
# 13  245.254710  8424  exhibitions
# 14   23.248981  5439  exhibitions
# 15   23.202024  5658  exhibitions
# 16   23.202024  5912  exhibitions
# 17   22.332485  6027  exhibitions
# 18   22.332485    74  exhibitions
# 19   22.202024  2281  exhibitions
# 20   21.495365  3615  exhibitions
# 21   21.495365  3903  exhibitions
# 22   21.495365  6535  exhibitions
# 23   21.473270  5410  exhibitions
# 24   20.727734  8242  exhibitions
# 25   19.368977  7095  exhibitions
# 26   19.368977  8218  exhibitions
# 27   18.764820  3449  exhibitions
# 28   18.203678  7457  exhibitions
# 29   17.764820  4468  exhibitions
# 30   17.681107  3037  exhibitions
# 31   17.203678  5896  exhibitions
# 32   17.193268  8577  exhibitions
# 33   16.681107  2924  exhibitions
# 34   16.234737  3095  exhibitions
# 35   15.906640  6296  exhibitions
# 36   14.833890  5593  exhibitions
# 37   14.833890  2102  exhibitions
#
#                                          api_link  \
# 0   https://api.artic.edu/api/v1/exhibitions/3070
# 1   https://api.artic.edu/api/v1/exhibitions/1865
# 2   https://api.artic.edu/api/v1/exhibitions/3672
# 3   https://api.artic.edu/api/v1/exhibitions/2518
# 4   https://api.artic.edu/api/v1/exhibitions/3390
# 5   https://api.artic.edu/api/v1/exhibitions/2835
# 6   https://api.artic.edu/api/v1/exhibitions/9639
# 7   https://api.artic.edu/api/v1/exhibitions/7177
# 8   https://api.artic.edu/api/v1/exhibitions/8423
# 9   https://api.artic.edu/api/v1/exhibitions/5874
# 10  https://api.artic.edu/api/v1/exhibitions/3389
# 11  https://api.artic.edu/api/v1/exhibitions/5757
# 12  https://api.artic.edu/api/v1/exhibitions/7780
# 13  https://api.artic.edu/api/v1/exhibitions/8424
# 14  https://api.artic.edu/api/v1/exhibitions/5439
# 15  https://api.artic.edu/api/v1/exhibitions/5658
# 16  https://api.artic.edu/api/v1/exhibitions/5912
# 17  https://api.artic.edu/api/v1/exhibitions/6027
# 18    https://api.artic.edu/api/v1/exhibitions/74
# 19  https://api.artic.edu/api/v1/exhibitions/2281
# 20  https://api.artic.edu/api/v1/exhibitions/3615
# 21  https://api.artic.edu/api/v1/exhibitions/3903
# 22  https://api.artic.edu/api/v1/exhibitions/6535
# 23  https://api.artic.edu/api/v1/exhibitions/5410
# 24  https://api.artic.edu/api/v1/exhibitions/8242
# 25  https://api.artic.edu/api/v1/exhibitions/7095
# 26  https://api.artic.edu/api/v1/exhibitions/8218
# 27  https://api.artic.edu/api/v1/exhibitions/3449
# 28  https://api.artic.edu/api/v1/exhibitions/7457
# 29  https://api.artic.edu/api/v1/exhibitions/4468
# 30  https://api.artic.edu/api/v1/exhibitions/3037
# 31  https://api.artic.edu/api/v1/exhibitions/5896
# 32  https://api.artic.edu/api/v1/exhibitions/8577
# 33  https://api.artic.edu/api/v1/exhibitions/2924
# 34  https://api.artic.edu/api/v1/exhibitions/3095
# 35  https://api.artic.edu/api/v1/exhibitions/6296
# 36  https://api.artic.edu/api/v1/exhibitions/5593
# 37  https://api.artic.edu/api/v1/exhibitions/2102
#
#                                                 title  \
# 0                                            Van Gogh
# 1                                 Van Gogh's Bedrooms
# 2                                    Vincent van Gogh
# 3                              Van Gogh: In Search Of
# 4     Gallery of Art Interpretation: Van Gogh, Artist
# 5       Van Gogh and Gauguin: The Studio of the South
# 6   Van Gogh and the Avant-Garde: The Modern Lands...
# 7   Leonardo to Van Gogh: Master Drawings from Bud...
# 8   Meet the Artists: Van Gogh and Gauguin: A Self...
# 9   Masterpiece of the Month: The Bedroom at Arles...
# 10  Masterpiece of the Month: Garden of the House ...
# 11  Paintings and Drawings by Vincent van Gogh, le...
# 12  Junior Museum: Portraits and Sunflowers of Vin...
# 13  The Yellow House: Van Gogh and Gaugiun Side by...
# 14                               Etchings by Van Dyck
# 15                 The Howard Van Doren Shaw Memorial
# 16                  Architecture by Mies van der Rohe
# 17                    Mies van der Rohe Retrospective
# 18                        The Iconography of Van Dyck
# 19        Van Dyck, Rembrandt, and the Portrait Print
# 20                 Works by Jean Emile van Cauwelaert
# 21              Photographs by Edouard van der Elsken
# 22          Lucas van Leyden, Engravings and Woodcuts
# 23  Prints by Martin Schongauer, Lucas van Leyden,...
# 24               On the Road to Italy: Jan van Scorel
# 25  Society for Contemporary Art 39th Annual: Ger ...
# 26  Van Eyck's “Annunciation”: The meeting of Heav...
# 27  Water Colors, Sketches, Drawings and Etchings ...
# 28  The Unknown Mies van der Rohe and His Disciple...
# 29  Views in the Canadian Rockies Photographed by ...
# 30  Architecture, English and American 18th Centur...
# 31  Masterpiece of the Month: The Adoration of the...
# 32  Room of Chicago Art: Paintings by Jean Crawfor...
# 33  Small Loan Collection including Paintings by K...
# 34  To Build a Modern Campus: Ludwig Mies van der ...
# 35  The Masterpiece of the Month: Christ Preaching...
# 36  Paintings by Tressa Emerson Benson, Fred Biese...
# 37  Paintings by Jean Crawford Adams, Emil Armin, ...
#
#                     timestamp
# 0   2025-02-17T23:38:33-06:00
# 1   2025-02-17T23:35:01-06:00
# 2   2025-02-05T17:25:07-06:00
# 3   2025-02-17T23:37:52-06:00
# 4   2025-02-05T17:25:04-06:00
# 5   2025-02-17T23:37:47-06:00
# 6   2025-02-17T23:34:40-06:00
# 7   2025-02-05T17:25:48-06:00
# 8   2025-02-05T17:26:05-06:00
# 9   2025-02-05T17:25:30-06:00
# 10  2025-02-05T17:25:04-06:00
# 11  2025-02-05T17:25:29-06:00
# 12  2025-02-05T17:25:54-06:00
# 13  2025-02-05T17:26:05-06:00
# 14  2025-02-05T17:25:26-06:00
# 15  2025-02-17T23:33:23-06:00
# 16  2025-02-17T23:33:14-06:00
# 17  2025-02-05T17:25:32-06:00
# 18  2025-02-05T17:24:31-06:00
# 19  2025-02-17T23:38:25-06:00
# 20  2025-02-05T17:25:07-06:00
# 21  2025-02-05T17:25:09-06:00
# 22  2025-02-05T17:25:38-06:00
# 23  2025-02-05T17:25:25-06:00
# 24  2025-02-05T17:26:02-06:00
# 25  2025-02-05T17:25:46-06:00
# 26  2025-02-05T17:26:01-06:00
# 27  2025-02-05T17:25:05-06:00
# 28  2025-02-05T17:25:50-06:00
# 29  2025-02-05T17:25:15-06:00
# 30  2025-02-05T17:24:59-06:00
# 31  2025-02-05T17:25:31-06:00
# 32  2025-02-05T17:26:07-06:00
# 33  2025-02-05T17:24:54-06:00
# 34  2025-02-17T23:38:24-06:00
# 35  2025-02-05T17:25:35-06:00
# 36  2025-02-05T17:25:28-06:00
# 37  2025-02-05T17:24:46-06:00

# %% [markdown]
# ## Possible available APIs with/without authorizations
#
# - See https://github.com/public-apis/public-apis.
# - See https://mixedanalytics.com/blog/list-actually-free-open-no-auth-needed-apis/.

# %% [markdown]
# ## Example with New York Times API

# %% [markdown]
# The New York Times API uses an API key to authenticate users.  The [FAQs](https://developer.nytimes.com/faq) page has some good information about the usage of these APIs.  You may request a NYT API key using the instructions listed in https://developer.nytimes.com/get-started.

# %% [markdown]
# ### Brief word about the use of an API key
# An API key is a unique generated string that
#
# - identifies a particular application (or project),
# - authenticates and grants access to a user,
# - provides guardrails to controlling API usage traffic, and
# - enables resource management over the flow of data.

# %% [markdown]
# ### Best practices in using an API key
#
# - **Do not** hardcode your API key into any scripts.
#   - For example, save your API key in a local file (or environment variables) and access it from your code.
# - **Do not** upload your API key anywhere publicly accessible.
# - Rotate API keys.
# - Revoke access after the lifespan of a project.

# %%
import requests
import pandas as pd

with open('../data/nyt_api.key', 'r') as f:
    apikey = f.readlines()[0]

# %%
# formatted string example
url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json?&api-key={:s}'.format(apikey)
url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?&api-key={apikey}'

# %% [markdown]
# ### Search articles
#
# Example API: https://developer.nytimes.com/docs/articlesearch-product/1/routes/articlesearch.json/get

# %%
import time
results_store = [] 
for i in range(5):
    if r.ok:
        result = r.json()
        results_store.append(result['response']['docs'])
    else:
        print('something went wrong!')
    time.sleep(12)

# %%
len(results_store[0])
# Out:
# 10

# %%
r = requests.get(url, params={'q':'microsoft',
                              'begin_date': '20240101',
                              'end_date': '20241231',
                              'sort': 'oldest'})

# %%
result = r.json()

# %%
result['response']['docs'][0]['pub_date']
# Out:
# '2024-01-02T20:43:17+0000'

# %%
import time

time.sleep(12)

# %%
result['response']['docs'][0]
# Out:
# {'abstract': 'Leonard Bernstein is coming back to New York City Center as part of a celebration of what would have been his 90th birthday.',
#  'web_url': 'https://www.nytimes.com/2008/05/12/theater/12arts-ENCORESFORBE_BRF.html',
#  'snippet': 'Leonard Bernstein is coming back to New York City Center as part of a celebration of what would have been his 90th birthday.',
#  'lead_paragraph': 'Leonard Bernstein is coming back to New York City Center as part of a celebration of what would have been his 90th birthday. For the first time, the City Center Encores! series will begin in the fall, with “On the Town,” the 1944 musical that Bernstein wrote with Betty Comden and Adolph Green. “On the Town” is scheduled to run from Nov. 19 to 23, followed by a production of the 1932 Jerome Kern-Oscar Hammerstein musical “Music in the Air” from Feb. 5 to 8. The season will conclude with “Finian’s Rainbow,” the 1949 musical by Burton Lane, E. Y. Harburg and Fred Saidy about what to do with an Irish pot of gold in the state of Missitucky. That is scheduled to run March 26 to 29.',
#  'print_section': 'E',
#  'print_page': '2',
#  'source': 'The New York Times',
#  'multimedia': [],
#  'headline': {'main': 'Encores! for Bernstein',
#   'kicker': 'Arts, Briefly',
#   'content_kicker': None,
#   'print_headline': 'Encores! For Bernstein',
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [{'name': 'subject',
#    'value': 'Encores! Great American Musicals in Concert (Series)',
#    'rank': 1,
#    'major': 'N'},
#   {'name': 'subject', 'value': 'Theater', 'rank': 2, 'major': 'N'},
#   {'name': 'persons', 'value': 'Bernstein, Leonard', 'rank': 3, 'major': 'N'}],
#  'pub_date': '2008-05-12T04:00:00+0000',
#  'document_type': 'article',
#  'news_desk': 'Culture',
#  'section_name': 'Theater',
#  'byline': {'original': 'By Campbell Robertson',
#   'person': [{'firstname': 'Campbell',
#     'middlename': None,
#     'lastname': 'Robertson',
#     'qualifier': None,
#     'title': None,
#     'role': 'reported',
#     'organization': '',
#     'rank': 1}],
#   'organization': None},
#  'type_of_material': 'Brief',
#  '_id': 'nyt://article/cff39034-1dd5-57f0-bfb6-5ca21ac5cbe7',
#  'word_count': 131,
#  'uri': 'nyt://article/cff39034-1dd5-57f0-bfb6-5ca21ac5cbe7'}

# %%
df = pd.DataFrame(result['response']['docs'])

# %%
df
# Out:
#                                             abstract  \
# 0  And a winter storm could dump up to a foot of ...
# 1  Widespread ice accumulations may lead to hazar...
# 2  Their feathers, roosting behaviors and adaptab...
# 3  The 17-member crew of the freighter, stuck a m...
# 4  A mass of air called the polar vortex has esca...
# 5  Although the last remaining precipitation was ...
# 6  Officials warned residents across the South th...
# 7  The figures are unofficial because National We...
# 8  Snow and cold temperatures hitting a broad swa...
# 9  Many roadways were impassable, classes were ca...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2025/02/18/weather/arc...
# 1  https://www.nytimes.com/2025/02/05/weather/ice...
# 2  https://www.nytimes.com/2025/01/29/realestate/...
# 3  https://www.nytimes.com/2025/01/25/nyregion/ca...
# 4  https://www.nytimes.com/2025/01/21/climate/why...
# 5  https://www.nytimes.com/2025/01/22/weather/sou...
# 6  https://www.nytimes.com/2025/01/23/us/snow-col...
# 7  https://www.nytimes.com/2025/01/22/weather/win...
# 8  https://www.nytimes.com/2025/01/21/weather/fli...
# 9  https://www.nytimes.com/2025/01/21/weather/new...
#
#                                              snippet  \
# 0  And a winter storm could dump up to a foot of ...
# 1  Widespread ice accumulations may lead to hazar...
# 2  Their feathers, roosting behaviors and adaptab...
# 3  The 17-member crew of the freighter, stuck a m...
# 4  A mass of air called the polar vortex has esca...
# 5  Although the last remaining precipitation was ...
# 6  Officials warned residents across the South th...
# 7  The figures are unofficial because National We...
# 8  Snow and cold temperatures hitting a broad swa...
# 9  Many roadways were impassable, classes were ca...
#
#                                       lead_paragraph              source  \
# 0  A powerful surge of arctic air from Canada des...  The New York Times
# 1  Waves of winter weather are expected to sweep ...  The New York Times
# 2  Winter mornings begin at David Sibley’s Deerfi...  The New York Times
# 3  A Canadian cargo freighter carrying 17 crew me...  The New York Times
# 4  The unusual gust of frigid air extending down ...  The New York Times
# 5  On Wednesday, a long stretch of the deep south...  The New York Times
# 6  After a rare winter storm walloped the souther...  The New York Times
# 7  Amid an extraordinary storm that delivered a b...  The New York Times
# 8  With winter weather striking the Southeastern ...  The New York Times
# 9  Weather upending routines and causing havoc is...  The New York Times
#
#                                           multimedia  \
# 0  [{'rank': 0, 'subtype': 'square320', 'caption'...
# 1  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4                                                 []
# 5                                                 []
# 6  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 7  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 8  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 9  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             headline  \
# 0  {'main': 'Arctic Air Mass Brings Dangerous Tem...
# 1  {'main': 'Freezing Rain and Messy Travel Expec...
# 2  {'main': 'The Birds’ Guide to Surviving Winter...
# 3  {'main': 'After 3 Days Trapped in Lake Erie Ic...
# 4  {'main': 'Why Is It So Cold in the South If th...
# 5  {'main': 'When Will the South Warm Up Again? N...
# 6  {'main': 'After Snow and Frigid Temperatures, ...
# 7  {'main': 'Here’s Where It Snowed the Most Acro...
# 8  {'main': 'Thousands of Flights Delayed or Canc...
# 9  {'main': 'New Orleans, a City That Has Seen It...
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Weather', 'rank...
# 1  [{'name': 'subject', 'value': 'Weather', 'rank...
# 2  [{'name': 'subject', 'value': 'Birds', 'rank':...
# 3  [{'name': 'glocations', 'value': 'Lake Erie', ...
# 4  [{'name': 'subject', 'value': 'Global Warming'...
# 5  [{'name': 'subject', 'value': 'Weather', 'rank...
# 6  [{'name': 'glocations', 'value': 'Southern Sta...
# 7  [{'name': 'subject', 'value': 'Snow and Snowst...
# 8  [{'name': 'subject', 'value': 'Delays (Transpo...
# 9  [{'name': 'subject', 'value': 'Snow and Snowst...
#
#                    pub_date document_type   news_desk section_name  \
# 0  2025-02-18T14:48:32+0000       article     Weather      Weather
# 1  2025-02-05T09:00:03+0000       article     Weather      Weather
# 2  2025-01-29T10:00:23+0000       article  RealEstate  Real Estate
# 3  2025-01-25T21:35:10+0000       article       Metro     New York
# 4  2025-01-21T20:36:07+0000       article     Climate      Climate
# 5  2025-01-22T18:03:32+0000       article     Weather      Weather
# 6  2025-01-23T10:02:15+0000       article    National         U.S.
# 7  2025-01-22T22:07:45+0000       article     Weather      Weather
# 8  2025-01-21T20:32:56+0000       article    National      Weather
# 9  2025-01-21T19:37:18+0000       article    National      Weather
#
#                                               byline type_of_material  \
# 0  {'original': 'By Nazaneen Ghaffar', 'person': ...             News
# 1  {'original': 'By Nazaneen Ghaffar and Judson J...             News
# 2  {'original': 'By Margaret Roach', 'person': [{...             News
# 3  {'original': 'By David Andreatta', 'person': [...             News
# 4  {'original': 'By Austyn Gaffney', 'person': [{...             News
# 5  {'original': 'By Judson Jones', 'person': [{'f...             News
# 6  {'original': 'By Eduardo Medina', 'person': [{...             News
# 7  {'original': 'By Amy Graff', 'person': [{'firs...             News
# 8  {'original': 'By Christine Chung', 'person': [...             News
# 9  {'original': 'By Katy Reckdahl and Rick Rojas'...             News
#
#                                                  _id  word_count  \
# 0  nyt://article/3f7121fc-64f3-577b-9b05-edff9459...         993
# 1  nyt://article/5cee321e-3b73-5b57-aee5-585928ee...         534
# 2  nyt://article/e28cb759-1673-58d8-9c55-4568539f...        1466
# 3  nyt://article/8c8f3d31-ab16-59d7-899c-5a9ce713...         756
# 4  nyt://article/68605806-3676-574a-9858-49ef7db6...         477
# 5  nyt://article/1eadb55b-5c5b-50b5-86c1-bca28b07...         270
# 6  nyt://article/d1bb9b9c-ea8c-51c2-b90f-47f12e61...         800
# 7  nyt://article/ac7f1014-864e-5f87-aa4a-2cc3ede4...         476
# 8  nyt://article/76d480d7-59ba-5fde-94ca-283cde44...         513
# 9  nyt://article/733ed940-201e-5e84-ae2d-55445602...         536
#
#                                                  uri print_section print_page
# 0  nyt://article/3f7121fc-64f3-577b-9b05-edff9459...           NaN        NaN
# 1  nyt://article/5cee321e-3b73-5b57-aee5-585928ee...           NaN        NaN
# 2  nyt://article/e28cb759-1673-58d8-9c55-4568539f...            RE          9
# 3  nyt://article/8c8f3d31-ab16-59d7-899c-5a9ce713...           NaN        NaN
# 4  nyt://article/68605806-3676-574a-9858-49ef7db6...           NaN        NaN
# 5  nyt://article/1eadb55b-5c5b-50b5-86c1-bca28b07...           NaN        NaN
# 6  nyt://article/d1bb9b9c-ea8c-51c2-b90f-47f12e61...             A         11
# 7  nyt://article/ac7f1014-864e-5f87-aa4a-2cc3ede4...           NaN        NaN
# 8  nyt://article/76d480d7-59ba-5fde-94ca-283cde44...           NaN        NaN
# 9  nyt://article/733ed940-201e-5e84-ae2d-55445602...           NaN        NaN

# %% [markdown]
# ### How many articles matched the search?

# %% [markdown]
# ### How many articles did we get?

# %% [markdown]
# ### How many articles are there for the last 10 years (2014 - 2024)?

# %% [markdown]
# ### How many articles are there in each of the last 10 years?

# %% [markdown]
# ### Get the first 50 articles

# %% [markdown]
# ## Practice - MTFBWY
#
# 1. Find out (if you don't already know) the year when the first Star Wars movie came out.
# 2. Retrieve the number of hits per year since then for the following terms:
#    - 'Carrie Fisher'
#    - 'Harrison Ford'
#    - 'Daisy Ridley'
#    - 'Star Wars'
#    - Add more if you wish...
# 3. Store the numbers into a dataframe.
# 4. Plot the number of hits against year on the same graph.
