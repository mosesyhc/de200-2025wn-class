# %% [markdown]
# # Entry survey
#
# Take a moment to fill out entry survey on Canvas.

# %% [markdown]
# # Know your neighbors
# Form a group of 3-4 (meet one new person!):
#
# 1. Name
# 2. Major
# 3. Year (Freshman, Sophomore, etc.)
# 4. Are you a dog/cat/other person? (there is no correct answer...)
# 5. What brings you to this class?
# 6. What do you hope to get out of the class?
